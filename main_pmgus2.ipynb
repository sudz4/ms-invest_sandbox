# %%
from polygon import RESTClient
import pandas as pd
import asyncio
import logging
from datetime import datetime, timedelta
import pytz
from typing import Dict, List, Optional

class PolygonMarketScanner:
    def __init__(
        self, 
        api_key: str,
        min_market_cap: float = 300e6,
        min_avg_volume: int = 100000,
        gap_threshold: float = 2.0,
    ):
        self.client = RESTClient(api_key)
        self.logger = logging.getLogger('PolygonScanner')
        self.logger.setLevel(logging.INFO)
        self.min_market_cap = min_market_cap
        self.min_avg_volume = min_avg_volume
        self.gap_threshold = gap_threshold
        self.semaphore = asyncio.Semaphore(200)
        self.processed_count = 0
        self.total_tickers = 0

    def _get_filtered_tickers(self) -> List[Dict]:
        """Get pre-filtered list of potential candidates"""
        print("Pre-filtering tickers...")
        candidates = []
        
        # Get base ticker list
        base_tickers = self.client.list_tickers(
            market="stocks",
            type="CS",
            active=True,
            limit=1000
        )
        
        # Get yesterday's date
        yesterday = (datetime.now() - timedelta(days=1)).strftime('%Y-%m-%d')
        
        for ticker in base_tickers:
            if ticker.primary_exchange not in ['XNYS', 'XNAS']:
                continue
                
            try:
                # Get ticker details first
                details = self.client.get_ticker_details(ticker.ticker)
                if not details or not details.market_cap or details.market_cap < self.min_market_cap:
                    continue
                
                # Quick volume check
                daily_aggs = list(self.client.list_aggs(
                    ticker.ticker,
                    multiplier=1,
                    timespan="day",
                    from_=yesterday,
                    to=yesterday,
                    limit=1
                ))
                
                if daily_aggs and daily_aggs[0].volume >= self.min_avg_volume:
                    candidates.append({
                        'symbol': ticker.ticker,
                        'market_cap': details.market_cap,
                        'name': details.name,
                        'prev_close': daily_aggs[0].close,
                        'prev_volume': daily_aggs[0].volume
                    })
                    
                    print(f"Pre-filtered: {ticker.ticker} | Cap: ${details.market_cap/1e9:.1f}B | "
                          f"Vol: {daily_aggs[0].volume:,}", end='\r')
                
            except Exception as e:
                continue
        
        print(f"\nFound {len(candidates)} potential candidates after pre-filtering")
        return candidates

    async def get_pre_market_data(self, symbol: str, prev_data: Dict, start_date: str) -> Optional[Dict]:
        """Get pre-market data for pre-filtered candidates"""
        try:
            async with self.semaphore, asyncio.timeout(1):
                # Get only pre-market data
                aggs = list(self.client.list_aggs(
                    ticker=symbol,
                    multiplier=1,
                    timespan="minute",
                    from_=start_date,
                    to=start_date,
                    limit=50000
                ))
                
                if not aggs:
                    return None

                current_price = aggs[-1].close
                current_volume = sum(agg.volume for agg in aggs)
                
                # Quick gap calculation
                gap_percent = ((current_price - prev_data['prev_close']) / 
                             prev_data['prev_close'] * 100)
                
                if gap_percent <= self.gap_threshold:
                    return None

                # Market cap categorization
                market_cap = prev_data['market_cap']
                if market_cap >= 200e9:
                    cap_type = 'Titans'
                elif market_cap >= 10e9:
                    cap_type = 'Large caps'
                elif market_cap >= 2e9:
                    cap_type = 'Mid caps'
                elif market_cap >= 300e6:
                    cap_type = 'Small caps'
                elif market_cap > 50e6:
                    cap_type = 'Micro caps'
                else:
                    cap_type = 'Shrimp'

                result = {
                    'symbol': symbol,
                    'name': prev_data['name'],
                    'market_cap': market_cap,
                    'market_cap_type': cap_type,
                    'gap_percent': round(gap_percent, 2),
                    'price': current_price,
                    'volume': current_volume,
                    'prev_close': prev_data['prev_close'],
                    'prev_volume': prev_data['prev_volume']
                }
                
                print(f"\nFound Gapper: {symbol:<6} | Gap: {gap_percent:>5.1f}% | "
                      f"{cap_type:<10} | ${market_cap/1e9:>6.1f}B | "
                      f"Vol: {current_volume:>10,}")
                
                return result

        except Exception as e:
            return None

    async def scan_pre_market(self) -> pd.DataFrame:
        start_time = datetime.now()
        print("\nStarting pre-market scan...")
        
        # Get pre-filtered candidates
        candidates = self._get_filtered_tickers()
        
        if not candidates:
            print("No candidates found after pre-filtering")
            return pd.DataFrame()
        
        # Get today's date
        today = datetime.now(pytz.timezone('US/Eastern')).strftime('%Y-%m-%d')
        
        # Process pre-filtered candidates
        tasks = [
            self.get_pre_market_data(
                candidate['symbol'], 
                candidate, 
                today
            ) 
            for candidate in candidates
        ]
        
        results = await asyncio.gather(*tasks)
        results = [r for r in results if r is not None]
        
        # Convert to DataFrame
        df = pd.DataFrame(results) if results else pd.DataFrame()
        
        if not df.empty:
            df = df.sort_values('gap_percent', ascending=False)
        
        execution_time = (datetime.now() - start_time).total_seconds()
        print(f"\nScan completed in {execution_time:.2f} seconds.")
        print(f"Found {len(df)} matching stocks")
        
        if not df.empty:
            print("\nTop 5 Pre-Market Gainers:")
            print(df.head().to_string())
        
        return df

async def get_pre_market_gainers(api_key: str) -> pd.DataFrame:
    scanner = PolygonMarketScanner(api_key)
    return await scanner.scan_pre_market()

# %%
import dotenv
import os
dotenv.load_dotenv()

api_key = os.getenv('polygonioKEY')

# %%
poly_preg_df = await get_pre_market_gainers(api_key)
# Out:
# Running in after-hours mode
#
# Starting after-hours scan...
# Fetching ticker list...
# Processing 4979 tickers...
#
# Found: AACT   | Change: $  0.00 |   0.1% | Vol: 1,604 | Session: after-hours
#
# Found: AADI   | Change: $  0.06 |   2.9% | Vol: 71,365 | Session: after-hours
#
# Found: AAON   | Change: $  2.86 |   2.1% | Vol: 327,370 | Session: after-hours
#
# Found: AAP    | Change: $  0.08 |   0.2% | Vol: 1,825,539 | Session: after-hours
#
# Found: AAPL   | Change: $  2.66 |   1.1% | Vol: 37,586,535.0 | Session: after-hours
#
# Found: AAT    | Change: $  0.38 |   1.3% | Vol: 152,713 | Session: after-hours
#
# Found: AB     | Change: $  0.49 |   1.4% | Vol: 415,768 | Session: after-hours
#
# Found: ABBV   | Change: $  4.44 |   2.5% | Vol: 5,452,743 | Session: after-hours
#
# Found: ABEO   | Change: $  0.09 |   1.5% | Vol: 197,126 | Session: after-hours
#
# Found: ABL    | Change: $  0.18 |   2.4% | Vol: 664,916 | Session: after-hours
#
# Found: ABLLL  | Change: $  0.09 |   0.3% | Vol: 2,167 | Session: after-hours
#
# Found: ABP    | Change: $  0.14 |   4.8% | Vol: 75,093 | Session: after-hours
#
# Found: ABR    | Change: $  0.05 |   0.3% | Vol: 1,679,204 | Session: after-hours
#
# Found: AC     | Change: $  1.02 |   2.8% | Vol: 10,658 | Session: after-hours
#
# Found: ACDC   | Change: $  0.58 |   7.4% | Vol: 636,219 | Session: after-hours
#
# Found: ACEL   | Change: $  0.07 |   0.6% | Vol: 336,995 | Session: after-hours
#
# Found: ACET   | Change: $  0.10 |  10.6% | Vol: 1,472,248 | Session: after-hours
#
# Found: ACHC   | Change: $  1.04 |   2.6% | Vol: 1,214,076 | Session: after-hours
#
# Found: ACI    | Change: $  0.16 |   0.8% | Vol: 1,592,611 | Session: after-hours
# Processed: 50/4979 tickers
# Found: ACLX   | Change: $  1.55 |   1.7% | Vol: 371,452 | Session: after-hours
#
# Found: ACN    | Change: $  2.64 |   0.7% | Vol: 1,703,697 | Session: after-hours
#
# Found: ACNT   | Change: $  0.24 |   2.2% | Vol: 2,620 | Session: after-hours
#
# Found: ACOG   | Change: $  0.23 |   3.9% | Vol: 127,251 | Session: after-hours
#
# Found: ACON   | Change: $  0.01 |   3.4% | Vol: 262,686 | Session: after-hours
#
# Found: ACRV   | Change: $  0.20 |   2.8% | Vol: 14,966 | Session: after-hours
#
# Found: ADBE   | Change: $  6.49 |   1.2% | Vol: 1,801,005 | Session: after-hours
#
# Found: ADC    | Change: $  0.56 |   0.7% | Vol: 412,956 | Session: after-hours
#
# Found: ADCT   | Change: $  0.22 |  10.8% | Vol: 630,771 | Session: after-hours
#
# Found: ADM    | Change: $  0.47 |   0.9% | Vol: 2,373,051 | Session: after-hours
#
# Found: ADMA   | Change: $  0.41 |   1.9% | Vol: 1,581,197 | Session: after-hours
#
# Found: ADP    | Change: $  3.53 |   1.2% | Vol: 745,415 | Session: after-hours
#
# Found: ADPT   | Change: $  0.10 |   1.8% | Vol: 1,516,353 | Session: after-hours
#
# Found: ADSE   | Change: $  0.41 |   3.1% | Vol: 70,228 | Session: after-hours
#
# Found: ADT    | Change: $  0.04 |   0.5% | Vol: 4,062,154 | Session: after-hours
#
# Found: ADUR   | Change: $  0.20 |   3.6% | Vol: 63,826 | Session: after-hours
#
# Found: ADUS   | Change: $  1.46 |   1.2% | Vol: 90,348 | Session: after-hours
#
# Found: ADVM   | Change: $  0.01 |   0.2% | Vol: 110,516 | Session: after-hours
#
# Found: AEE    | Change: $  0.74 |   0.8% | Vol: 560,217 | Session: after-hours
# Processed: 100/4979 tickers
# Found: AEM    | Change: $  2.38 |   2.9% | Vol: 1,766,458 | Session: after-hours
#
# Found: AEMD   | Change: $  0.00 |   0.5% | Vol: 74,812 | Session: after-hours
#
# Found: AENT   | Change: $  0.21 |   4.3% | Vol: 42,533 | Session: after-hours
#
# Found: AEP    | Change: $  1.29 |   1.3% | Vol: 1,280,239 | Session: after-hours
#
# Found: AER    | Change: $  0.61 |   0.6% | Vol: 799,771 | Session: after-hours
#
# Found: AEVA   | Change: $  0.09 |   2.0% | Vol: 488,343 | Session: after-hours
#
# Found: AFBI   | Change: $  0.17 |   0.8% | Vol: 1,738 | Session: after-hours
#
# Found: AFL    | Change: $  0.82 |   0.7% | Vol: 831,205 | Session: after-hours
#
# Found: AFYA   | Change: $  0.20 |   1.2% | Vol: 81,350 | Session: after-hours
#
# Found: AG     | Change: $  0.02 |   0.3% | Vol: 6,468,591 | Session: after-hours
#
# Found: AGFY   | Change: $ 18.19 |  39.7% | Vol: 445,954 | Session: after-hours
#
# Found: AGI    | Change: $  0.08 |   0.4% | Vol: 1,745,030 | Session: after-hours
#
# Found: AGIO   | Change: $  1.59 |   2.8% | Vol: 406,232 | Session: after-hours
#
# Found: AGM    | Change: $  0.76 |   0.4% | Vol: 19,120 | Session: after-hours
#
# Found: AGNCO  | Change: $  0.03 |   0.1% | Vol: 32,838 | Session: after-hours
#
# Found: AGR    | Change: $  0.02 |   0.1% | Vol: 278,569 | Session: after-hours
#
# Found: AGRO   | Change: $  0.03 |   0.3% | Vol: 471,787 | Session: after-hours
#
# Found: AGX    | Change: $  6.48 |   4.1% | Vol: 179,816 | Session: after-hours
#
# Found: AHH    | Change: $  0.15 |   1.4% | Vol: 425,936 | Session: after-hours
#
# Found: AHR    | Change: $  0.69 |   2.4% | Vol: 1,484,499 | Session: after-hours
#
# Found: AIG    | Change: $  0.35 |   0.5% | Vol: 2,813,124 | Session: after-hours
# Processed: 150/4979 tickers
# Found: AIMD   | Change: $  0.01 |   2.9% | Vol: 30,816 | Session: after-hours
#
# Found: AIP    | Change: $  0.22 |   2.6% | Vol: 198,979 | Session: after-hours
#
# Found: AIRE   | Change: $  0.03 |   2.9% | Vol: 65,968 | Session: after-hours
#
# Found: AIRG   | Change: $  0.03 |   0.3% | Vol: 20,472 | Session: after-hours
#
# Found: AIRJ   | Change: $  0.18 |   2.2% | Vol: 31,089 | Session: after-hours
#
# Found: AIRT   | Change: $  0.78 |   3.9% | Vol: 7,302 | Session: after-hours
#
# Found: AIT    | Change: $  1.94 |   0.7% | Vol: 253,642 | Session: after-hours
#
# Found: AIV    | Change: $  0.06 |   0.7% | Vol: 279,519 | Session: after-hours
#
# Found: AIZ    | Change: $  1.24 |   0.6% | Vol: 232,564 | Session: after-hours
#
# Found: AJG    | Change: $  6.57 |   2.1% | Vol: 1,106,240 | Session: after-hours
#
# Found: AJX    | Change: $  0.02 |   0.7% | Vol: 143,923 | Session: after-hours
#
# Found: AKAN   | Change: $  0.11 |   7.3% | Vol: 256,271 | Session: after-hours
#
# Found: AKBA   | Change: $  0.12 |   6.2% | Vol: 3,792,158 | Session: after-hours
#
# Found: AKR    | Change: $  0.04 |   0.2% | Vol: 738,886 | Session: after-hours
#
# Found: AKTS   | Change: $  0.01 |   7.5% | Vol: 12,706,433 | Session: after-hours
#
# Found: AKYA   | Change: $  0.13 |   6.1% | Vol: 108,875 | Session: after-hours
#
# Found: ALBT   | Change: $  0.08 |   3.0% | Vol: 131,844 | Session: after-hours
#
# Found: ALC    | Change: $  0.82 |   0.9% | Vol: 858,653 | Session: after-hours
#
# Found: ALCO   | Change: $  0.45 |   1.7% | Vol: 23,487 | Session: after-hours
#
# Found: ALEX   | Change: $  0.22 |   1.1% | Vol: 249,703 | Session: after-hours
#
# Found: ALF    | Change: $  0.00 |   0.0% | Vol: 4,492 | Session: after-hours
#
# Found: ALGS   | Change: $  1.34 |   6.5% | Vol: 359,405 | Session: after-hours
#
# Found: ALL    | Change: $  5.84 |   2.9% | Vol: 1,268,712 | Session: after-hours
#
# Found: ALLK   | Change: $  0.06 |   6.5% | Vol: 68,654 | Session: after-hours
# Processed: 200/4979 tickers
# Found: ALLO   | Change: $  0.20 |   8.8% | Vol: 4,930,033 | Session: after-hours
#
# Found: ALLT   | Change: $  0.05 |   1.1% | Vol: 696,600 | Session: after-hours
#
# Found: ALLY   | Change: $  0.07 |   0.2% | Vol: 2,447,782 | Session: after-hours
#
# Found: ALMS   | Change: $  0.05 |   0.6% | Vol: 50,577 | Session: after-hours
#
# Found: ALNT   | Change: $  0.07 |   0.3% | Vol: 242,652 | Session: after-hours
#
# Found: ALNY   | Change: $  2.37 |   0.9% | Vol: 799,275 | Session: after-hours
#
# Found: ALOT   | Change: $  0.29 |   1.9% | Vol: 1,003 | Session: after-hours
#
# Found: ALRN   | Change: $  0.14 |   5.7% | Vol: 34,793 | Session: after-hours
#
# Found: ALSN   | Change: $  0.37 |   0.3% | Vol: 265,293 | Session: after-hours
#
# Found: ALTO   | Change: $  0.02 |   1.4% | Vol: 440,078 | Session: after-hours
#
# Found: ALTS   | Change: $  0.03 |   1.4% | Vol: 45,932 | Session: after-hours
#
# Found: ALXO   | Change: $  0.02 |   1.4% | Vol: 504,096 | Session: after-hours
#
# Found: AM     | Change: $  0.19 |   1.2% | Vol: 1,336,851 | Session: after-hours
#
# Found: AMBA   | Change: $ 16.41 |  24.4% | Vol: 2,262,578 | Session: after-hours
#
# Found: AMED   | Change: $  0.05 |   0.1% | Vol: 128,628 | Session: after-hours
#
# Found: AMG    | Change: $  0.06 |   0.0% | Vol: 93,701 | Session: after-hours
#
# Found: AMH    | Change: $  0.27 |   0.7% | Vol: 1,885,835 | Session: after-hours
#
# Found: AMLI   | Change: $  0.00 |   0.5% | Vol: 267,747 | Session: after-hours
#
# Found: AMP    | Change: $  3.80 |   0.7% | Vol: 204,726 | Session: after-hours
# Processed: 250/4979 tickers
# Found: AMRC   | Change: $  0.01 |   0.0% | Vol: 250,138 | Session: after-hours
#
# Found: AMSF   | Change: $  0.40 |   0.7% | Vol: 55,963 | Session: after-hours
#
# Found: AMT    | Change: $  0.45 |   0.2% | Vol: 1,476,943 | Session: after-hours
#
# Found: AMZN   | Change: $  6.56 |   3.3% | Vol: 37,751,135 | Session: after-hours
#
# Found: AN     | Change: $  0.08 |   0.0% | Vol: 536,533 | Session: after-hours
#
# Found: ANAB   | Change: $  1.15 |   4.8% | Vol: 606,556 | Session: after-hours
#
# Found: ANET   | Change: $  8.28 |   2.1% | Vol: 1,536,293 | Session: after-hours
#
# Found: ANGH   | Change: $  0.03 |   4.4% | Vol: 6,599 | Session: after-hours
#
# Found: ANIK   | Change: $  0.53 |   3.0% | Vol: 58,198 | Session: after-hours
#
# Found: ANNX   | Change: $  0.19 |   3.7% | Vol: 1,277,789 | Session: after-hours
#
# Found: AON    | Change: $  0.53 |   0.1% | Vol: 745,841 | Session: after-hours
#
# Found: AORT   | Change: $  0.25 |   0.9% | Vol: 105,555 | Session: after-hours
#
# Found: AOUT   | Change: $  0.21 |   2.2% | Vol: 29,628 | Session: after-hours
#
# Found: APAM   | Change: $  0.43 |   0.9% | Vol: 243,297 | Session: after-hours
#
# Found: APCX   | Change: $  0.02 |   4.8% | Vol: 83,036 | Session: after-hours
#
# Found: APD    | Change: $  0.81 |   0.2% | Vol: 626,281 | Session: after-hours
#
# Found: APEI   | Change: $  0.04 |   0.2% | Vol: 61,953 | Session: after-hours
# Processed: 300/4979 tickers
# Found: APGE   | Change: $  0.11 |   0.2% | Vol: 394,158 | Session: after-hours
#
# Found: APH    | Change: $  0.56 |   0.8% | Vol: 3,434,558 | Session: after-hours
#
# Found: APLS   | Change: $  0.79 |   2.5% | Vol: 1,383,312 | Session: after-hours
#
# Found: APLT   | Change: $  0.52 |   5.4% | Vol: 2,348,199 | Session: after-hours
#
# Found: APO    | Change: $  1.48 |   0.8% | Vol: 2,377,077 | Session: after-hours
#
# Found: APOG   | Change: $  0.32 |   0.4% | Vol: 99,904 | Session: after-hours
#
# Found: APP    | Change: $ 11.25 |   3.5% | Vol: 4,065,914 | Session: after-hours
#
# Found: APPF   | Change: $  4.34 |   1.7% | Vol: 123,789 | Session: after-hours
#
# Found: APRE   | Change: $  0.06 |   2.1% | Vol: 4,588 | Session: after-hours
#
# Found: APTO   | Change: $  0.01 |   3.1% | Vol: 622,752 | Session: after-hours
#
# Found: APVO   | Change: $  0.04 |  11.6% | Vol: 3,016,272 | Session: after-hours
#
# Found: APXI   | Change: $  0.01 |   0.1% | Vol: 1,500 | Session: after-hours
#
# Found: APYX   | Change: $  0.01 |   0.7% | Vol: 40,109 | Session: after-hours
#
# Found: AQST   | Change: $  0.04 |   0.8% | Vol: 1,468,325 | Session: after-hours
#
# Found: AR     | Change: $  0.15 |   0.5% | Vol: 2,386,253 | Session: after-hours
#
# Found: ARBB   | Change: $  0.02 |   4.3% | Vol: 138,968 | Session: after-hours
#
# Found: ARBE   | Change: $  0.12 |   6.2% | Vol: 322,559 | Session: after-hours
#
# Found: ARCB   | Change: $  0.47 |   0.4% | Vol: 131,371 | Session: after-hours
#
# Found: ARCC   | Change: $  0.03 |   0.1% | Vol: 3,662,894 | Session: after-hours
#
# Found: ARDX   | Change: $  0.11 |   2.1% | Vol: 2,831,021 | Session: after-hours
#
# Found: AREB   | Change: $  0.15 |   7.0% | Vol: 19,608 | Session: after-hours
#
# Found: ARES   | Change: $  2.80 |   1.6% | Vol: 1,472,319 | Session: after-hours
#
# Found: ARI    | Change: $  0.03 |   0.3% | Vol: 487,450 | Session: after-hours
#
# Found: ARIS   | Change: $  0.18 |   0.7% | Vol: 266,538 | Session: after-hours
#
# Found: ARKR   | Change: $  0.05 |   0.5% | Vol: 9,983 | Session: after-hours
#
# Found: ARMK   | Change: $  0.70 |   1.7% | Vol: 2,327,114 | Session: after-hours
# Processed: 350/4979 tickers
# Found: ARMK   | Change: $  0.70 |   1.7% | Vol: 2,327,114 | Session: after-hours
#
# Found: ARQT   | Change: $  0.75 |   7.0% | Vol: 2,365,883 | Session: after-hours
#
# Found: ARWR   | Change: $  2.88 |  15.3% | Vol: 7,798,306 | Session: after-hours
#
# Found: AS     | Change: $  0.09 |   0.3% | Vol: 1,292,744 | Session: after-hours
#
# Found: ASMB   | Change: $  0.20 |   1.4% | Vol: 36,696 | Session: after-hours
#
# Found: ASPS   | Change: $  0.07 |   9.2% | Vol: 95,917 | Session: after-hours
#
# Found: ASRV   | Change: $  0.01 |   0.3% | Vol: 16,024 | Session: after-hours
#
# Found: ASST   | Change: $  0.00 |   0.6% | Vol: 302,905 | Session: after-hours
#
# Found: ASTC   | Change: $  0.09 |   1.2% | Vol: 4,137 | Session: after-hours
#
# Found: ASTH   | Change: $  0.06 |   0.1% | Vol: 259,883 | Session: after-hours
#
# Found: ATAI   | Change: $  0.05 |   3.0% | Vol: 1,105,126 | Session: after-hours
#
# Found: ATEN   | Change: $  0.50 |   3.0% | Vol: 946,417 | Session: after-hours
#
# Found: ATEX   | Change: $  0.16 |   0.5% | Vol: 286,795 | Session: after-hours
#
# Found: ATHA   | Change: $  0.02 |   3.5% | Vol: 155,957 | Session: after-hours
#
# Found: ATI    | Change: $  0.48 |   0.8% | Vol: 723,060 | Session: after-hours
# Processed: 400/4979 tickers
# Found: ATKR   | Change: $  0.34 |   0.4% | Vol: 1,041,536 | Session: after-hours
#
# Found: ATO    | Change: $  0.15 |   0.1% | Vol: 375,568 | Session: after-hours
#
# Found: ATOS   | Change: $  0.02 |   1.5% | Vol: 609,828 | Session: after-hours
#
# Found: ATPC   | Change: $  0.01 |   0.6% | Vol: 14,464 | Session: after-hours

# %%
print(len(poly_preg_df))
# Out:
# 0
